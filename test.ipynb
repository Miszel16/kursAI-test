# %% [markdown]
# <a href="https://colab.research.google.com/github/Miszel16/kursAI-test/blob/main/test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **# Podstawowe elementy języka python**
#
# *W tym rozdziale przedstawimy podstawowe elementy składni języka Python.*
#
#
# [Dokumnetacja Pythona](https://www.python.org/)
#
# ---
# 1. Zmienne
# ---
# 2. Listy
# ---
# 3. Pętle
# ---
# 4. Słowniki i krotki
# ---
# 5. Instrukcje warunkowe
# ---
# 6. Funkcje
# ---
# 7. Obsługa plików
# ---
# 8. Obsługa wyjątków
# ---

# %%
# !git init
# !git config --global user.name "Miszel16"
# !git config --global user.email "a.plachimowicz16@email.com"

# %%
# !git add .

# %%
# !git commit -m "inicjalizacja projektu"

# %%
# !git branch -M main

# %%
# !git remote add origin https://PAT@github.com/Miszel16/kursAI-test.git

# %%
# !git push -u origin main
